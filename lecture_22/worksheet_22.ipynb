# %% [markdown]
# # Worksheet 22
#
# Name: Jian Xie
# UID: U75516303
#
# ### Topics
#
# - Neural Networks
#
# ## Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
from tensorflow.python.keras.optimizer_v2.adam import Adam
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu
 
#       x[0] --- h1 
#            \ /    \
#             X       output
#            / \    /
#       x[1] --- h2
#
# This is the base model - nothing fancy here

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])
colors = np.hstack([colors] * 20)

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# LINE
def generate_line_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

PLOT_HIDDEN_LAYER_2D = False
PLOT_HIDDEN_LAYER_3D = True

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.03))

# X, Y = generate_circle_data(t)
# X, Y = generate_line_data(t)
# X, Y = generate_curve_data(t)
X, Y = generate_xor_data()

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=2, epochs=3000)

if PLOT_HIDDEN_LAYER_2D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    plt.scatter(layerVals[:,0], layerVals[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .02  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel()]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
    ax.set_xlabel("h0")
    ax.set_ylabel("h1")
    plt.show()

if PLOT_HIDDEN_LAYER_3D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(layerVals[:,0], layerVals[:, 1], layerVals[:, 2], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .1  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel(), np.zeros(len(xx.ravel()))]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=3, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired) # plot in 2D
    ax.axis('off')

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9) # plot in 2D
    plt.show()

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
T = model.predict(X)
T = np.array([0 if x < .5 else 1 for x in T])
T = T.reshape(X[:,0].shape)
ax.scatter(X[:, 0], X[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6978
# Epoch 2/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6943
# Epoch 3/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6937
# Epoch 4/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6943
# Epoch 5/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7033
# Epoch 6/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6936
# Epoch 7/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6987
# Epoch 8/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6972
# Epoch 9/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6939
# Epoch 10/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6936
# Epoch 11/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6961
# Epoch 12/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6935
# Epoch 13/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 14/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6932
# Epoch 15/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6931
# Epoch 16/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6958
# Epoch 17/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6931
# Epoch 18/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6930
# Epoch 19/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6976
# Epoch 20/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6930
# Epoch 21/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6931
# Epoch 22/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6930
# Epoch 23/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6930
# Epoch 24/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6930
# Epoch 25/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6930
# Epoch 26/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6929
# Epoch 27/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6930
# Epoch 28/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6968
# Epoch 29/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6929
# Epoch 30/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6930
# Epoch 31/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6963
# Epoch 32/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6959
# Epoch 33/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6929
# Epoch 34/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6976
# Epoch 35/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6928
# Epoch 36/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6928
# Epoch 37/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6928
# Epoch 38/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6928
# Epoch 39/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6964
# Epoch 40/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6927
# Epoch 41/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6927
# Epoch 42/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6961
# Epoch 43/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6957
# Epoch 44/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6970
# Epoch 45/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6957
# Epoch 46/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6926
# Epoch 47/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6926
# Epoch 48/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6956
# Epoch 49/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6965
# Epoch 50/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6960
# Epoch 51/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6926
# Epoch 52/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6925
# Epoch 53/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6925
# Epoch 54/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6955
# Epoch 55/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6963
# Epoch 56/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6924
# Epoch 57/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6954
# Epoch 58/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6950
# Epoch 59/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6923
# Epoch 60/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6962
# Epoch 61/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6922
# Epoch 62/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6950
# Epoch 63/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6947
# Epoch 64/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6960
# Epoch 65/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6920
# Epoch 66/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6954
# Epoch 67/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6950
# Epoch 68/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6920
# Epoch 69/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6919
# Epoch 70/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6918
# Epoch 71/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6945
# Epoch 72/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6954
# Epoch 73/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6916
# Epoch 74/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6916
# Epoch 75/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.
3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1122
# Epoch 439/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1115
# Epoch 440/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1108
# Epoch 441/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1104
# Epoch 442/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1095
# Epoch 443/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1089
# Epoch 444/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1083
# Epoch 445/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1076
# Epoch 446/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1072
# Epoch 447/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1064
# Epoch 448/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1060
# Epoch 449/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1052
# Epoch 450/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1046
# Epoch 451/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1042
# Epoch 452/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1034
# Epoch 453/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1028
# Epoch 454/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1022
# Epoch 455/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1017
# Epoch 456/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1011
# Epoch 457/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 458/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1002
# Epoch 459/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0995
# Epoch 460/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0991
# Epoch 461/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0984
# Epoch 462/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0979
# Epoch 463/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0975
# Epoch 464/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0968
# Epoch 465/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0965
# Epoch 466/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0958
# Epoch 467/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0954
# Epoch 468/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0949
# Epoch 469/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0943
# Epoch 470/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0939
# Epoch 471/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0933
# Epoch 472/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0928
# Epoch 473/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0923
# Epoch 474/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0920
# Epoch 475/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0914
# Epoch 476/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0911
# Epoch 477/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0905
# Epoch 478/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0901
# Epoch 479/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0897
# Epoch 480/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0892
# Epoch 481/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0886
# Epoch 482/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0882
# Epoch 483/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0879
# Epoch 484/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0873
# Epoch 485/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0869
# Epoch 486/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0865
# Epoch 487/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0861
# Epoch 488/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0856
# Epoch 489/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 490/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0848
# Epoch 491/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0844
# Epoch 492/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0840
# Epoch 493/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0836
# Epoch 494/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 495/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0829
# Epoch 496/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0825
# Epoch 497/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0821
# Epoch 498/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0817
# Epoch 499/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 500/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0810
# Epoch 501/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0805
# Epoch 502/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0801
# Epoch 503/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0797
# Epoch 504/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0795
# Epoch 505/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0790
# Epoch 506/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0786
# Epoch 507/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0784
# Epoch 508/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0779
# Epoch 509/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0777
# Epoch 510/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0772
# Epoch 511/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0769
# Epoch 512/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0766
# Epoch 513/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0762
# Epoch 514/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0759
# Epoch 515/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0755
# Epoch 516/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 517/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0748
# Epoch 518/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0745
# Epoch 519/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0742
# Epoch 520/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0738
# Epoch 521/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0736
# Epoch 522/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0733
# Epoch 523/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0730
# Epoch 524/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0727
# Epoch 525/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0723
# Epoch 526/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0720
# Epoch 527/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0718
# Epoch 528/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0713
# Epoch 529/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0710
# Epoch 530/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0708
# Epoch 531/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0705
# Epoch 532/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 533/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0699
# Epoch 534/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 535/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0693
# Epoch 536/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0690
# Epoch 537/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0687
# Epoch 538/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0684
# Epoch 539/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0682
# Epoch 540/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0678
# Epoch 541/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0675
# Epoch 542/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0673
# Epoch 543/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0670
# Epoch 544/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 545/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 546/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0662
# Epoch 547/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0659
# Epoch 548/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0657
# Epoch 549/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0654
# Epoch 550/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0651
# Epoch 551/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0649
# Epoch 552/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0646
# Epoch 553/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0644
# Epoch 554/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0641
# Epoch 555/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0638
# Epoch 556/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0636
# Epoch 557/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0634
# Epoch 558/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0632
# Epoch 559/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0629
# Epoch 560/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0626
# Epoch 561/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0624
# Epoch 562/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0621
# Epoch 563/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0619
# Epoch 564/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0617
# Epoch 565/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0614
# Epoch 566/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0612
# Epoch 567/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0610
# Epoch 568/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0608
# Epoch 569/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0605
# Epoch 570/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0602
# Epoch 571/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 572/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0598
# Epoch 573/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0596
# Epoch 574/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0594
# Epoch 575/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0592
# Epoch 576/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0589
# Epoch 577/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0587
# Epoch 578/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0585
# Epoch 579/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0583
# Epoch 580/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0580
# Epoch 581/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0578
# Epoch 582/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0576
# Epoch 583/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0574
# Epoch 584/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0572
# Epoch 585/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0570
# Epoch 586/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0568
# Epoch 587/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0566
# Epoch 588/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 589/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0562
# Epoch 590/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0560
# Epoch 591/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0557
# Epoch 592/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0556
# Epoch 593/3000
# ...
# Epoch 2814/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 2815/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 2816/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 2817/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2818/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2819/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 2820/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 2821/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 2822/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2823/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2824/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2825/3000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 2826/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2827/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2828/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 2829/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2830/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 2831/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2832/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2833/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2834/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2835/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2836/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 2837/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2838/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2839/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2840/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2841/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2842/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2843/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 2844/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 2845/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2846/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2847/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2848/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2849/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2850/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 2851/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 2852/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2853/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2854/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2855/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2856/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 2857/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 2858/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 2859/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2860/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2861/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2862/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2863/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2864/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 2865/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2866/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2867/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2868/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2869/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2870/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 2871/3000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 2872/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 2873/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2874/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2875/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2876/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 2877/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 2878/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2879/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2880/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2881/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2882/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 2883/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2884/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 2885/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 2886/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2887/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2888/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2889/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2890/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2891/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 2892/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 2893/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2894/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2895/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 2896/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2897/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 2898/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 2899/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2900/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2901/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2902/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2903/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 2904/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 2905/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2906/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2907/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 2908/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2909/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2910/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2911/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 2912/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2913/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2914/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2915/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2916/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2917/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2918/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 2919/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 2920/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 2921/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2922/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2923/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2924/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 2925/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 2926/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2927/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2928/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2929/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2930/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2931/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 2932/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 2933/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2934/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2935/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2936/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2937/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2938/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 2939/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2940/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2941/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2942/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 2943/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 2944/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2945/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2946/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2947/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 2948/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2949/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2950/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2951/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2952/3000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 2953/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 2954/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 2955/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2956/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2957/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2958/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 2959/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 2960/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2961/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2962/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2963/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2964/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 2965/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 2966/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 2967/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2968/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 2969/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2970/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2971/3000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 2972/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2973/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 2974/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 2975/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 2976/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2977/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2978/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2979/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2980/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2981/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2982/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2983/3000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 2984/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2985/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2986/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2987/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2988/3000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 2989/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 2990/3000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 2991/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2992/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2993/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2994/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 2995/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2996/3000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 2997/3000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 2998/3000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 2999/3000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 3000/3000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0014
# {'name': 'dense_84', 'trainable': True, 'batch_input_shape': (None, 2), 'dtype': 'float32', 'units': 3, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[  7.3958564,  14.754599 ,   9.346426 ],
#        [  7.994364 , -11.1955   , -12.843766 ]], dtype=float32), array([-1.8935629,  4.3047504, -3.729496 ], dtype=float32)]
